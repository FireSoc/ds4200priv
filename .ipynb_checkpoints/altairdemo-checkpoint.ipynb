# %%
import pandas as pd

# %%
import numpy as np
import altair as alt

# %%
df = pd.read_csv('data/Armenia.csv')

# %%
df
# Out:
#     CountryName Vaccine  Year Source  Value    Level
# 0       Armenia     bcg  1997    gov     72  percent
# 1       Armenia     bcg  1998    gov     95  percent
# 2       Armenia     bcg  1999    gov     93  percent
# 3       Armenia     bcg  2000    gov     97  percent
# 4       Armenia     bcg  2001    gov     96  percent
# ..          ...     ...   ...    ...    ...      ...
# 202     Armenia   rotac  2017    gov     94  percent
# 203     Armenia   rotac  2018    gov     93  percent
# 204     Armenia   rotac  2019    gov     92  percent
# 205     Armenia   rotac  2020    gov     92  percent
# 206     Armenia   rotac  2021    gov     92  percent
#
# [207 rows x 6 columns]

# %%
for col in df.columns:
    print(col, ":", df[col].unique())
# Out:
# CountryName : ['Armenia']
# Vaccine : ['bcg' 'dtp1' 'dtp3' 'hepb3' 'hepbb' 'hib3' 'ipv1' 'mcv1' 'mcv2' 'pcv3'
#  'pol3' 'rotac']
# Year : [1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010
#  2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021]
# Source : ['gov']
# Value : [72 95 93 97 96 92 94 91 98 99 88 82 90 87 89 55 69 78 85 34 79 62 44 86]
# Level : ['percent']

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# %%
alt.Chart(df).mark_point().encode(
    x = alt.X("Year:T"),
    y = alt.Y("Value:Q")
    
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_line().encode(
    x = alt.X("Year:T"),
    y = alt.Y("Value:Q"),
    color = alt.Color("Vaccine:N"),
    column = alt.Column("Vaccine:N"),
).properties(width=100, height=100)
# Out:
# alt.Chart(...)
